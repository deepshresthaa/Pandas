# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv("/workspaces/Pandas/pandas_dataframe/movies.csv")
movies

# %% [markdown]
# Movies with rating higher than 8 and votes > 10000

# %%
movies[(movies['imdb_rating']>8 )& (movies['imdb_votes']>10000)][['title_x','imdb_rating',"imdb_votes"]]
# Out:
#                           title_x  imdb_rating  imdb_votes
# 0        Uri: The Surgical Strike          8.4       35112
# 11                      Gully Boy          8.2       22440
# 37              Article 15 (film)          8.3       13417
# 40                Super 30 (film)          8.2       13972
# 143                       Tumbbad          8.2       16535
# 146                     Andhadhun          8.4       51615
# 325              Pink (2016 film)          8.2       33902
# 354                 Dangal (film)          8.4      131338
# 418                        Masaan          8.1       19904
# 426          Drishyam (2015 film)          8.2       58340
# 436                 Talvar (film)          8.2       26612
# 469             Queen (2014 film)          8.2       56406
# 536                 Haider (film)          8.1       46912
# 566                   Ugly (film)          8.1       17483
# 567                     PK (film)          8.1      143605
# ...

# %% [markdown]
# Action movies with rating higher than 7.5

# %%
movies[(movies['genres'].str.split("|").apply(lambda x: 'Action' in x)) & (movies['imdb_rating']>7.5)][['genres','imdb_rating']]
# Out:
#                        genres  imdb_rating
# 0            Action|Drama|War          8.4
# 41               Action|Drama          9.4
# 84         Action|Drama|Sport          8.1
# 106     Action|Drama|Thriller          7.8
# 110      Action|Drama|History          7.7
# 112              Action|Drama          7.6
# 169       Action|Thriller|War          7.6
# 219      Action|Drama|History          8.3
# 258        Action|Drama|Sport          7.6
# 280        Action|Crime|Drama          8.0
# 297        Action|Crime|Drama          7.8
# 354    Action|Biography|Drama          8.4
# 362       Action|Comedy|Drama          8.0
# 365           Action|Thriller          8.0
# 393   Action|Mystery|Thriller          7.6
# 449     Action|Drama|Thriller          7.6
# 536        Action|Crime|Drama          8.1
# 589           Action|Thriller          8.2
# 625     Action|Drama|Thriller          7.7
# 668    Action|Biography|Crime          8.2
# 693       Action|Comedy|Crime          8.2
# ...
