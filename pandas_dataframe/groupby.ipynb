# %% [markdown]
# groupby()

# %%
#groupby is a concept of grouping data on the basis of categorical columns

# %%
import pandas as pd
import numpy as np
movies=pd.read_csv("/workspaces/Pandas/pandas_dataframe/imdb-top-1000.csv")
movies.head(1)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
#1. Find the top 3 genres by total earning
movies.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
#2. Find the genre with highest average imbd rating
movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
#3. Find director with most popularity on the basis of highest voting
movies.groupby("Director")['No_of_Votes'].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
#4. Find the highest rated movie of each genre
movies.groupby('Genre')['IMDB_Rating'].max()
# Out:
# Genre
# Action       9.0
# Adventure    8.6
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.2
# Drama        9.3
# Family       7.8
# Fantasy      8.1
# Film-Noir    8.1
# Horror       8.5
# Mystery      8.4
# Thriller     7.8
# Western      8.8
# Name: IMDB_Rating, dtype: float64

# %%
#5 find no. of movies done by each actor
movies['Star1'].value_counts()
# Out:
# Star1
# Tom Hanks          12
# Robert De Niro     11
# Al Pacino          10
# Clint Eastwood     10
# Humphrey Bogart     9
#                    ..
# Preity Zinta        1
# Javier Bardem       1
# Ki-duk Kim          1
# Vladimir Garin      1
# Robert Donat        1
# Name: count, Length: 660, dtype: int64

# %%
#second way(without value_counts())
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks    12
# Name: Series_Title, dtype: int64

# %% [markdown]
# Groupby attributes and methods

# %%
#i. len()--> find total number of groups
a=len(movies.groupby('Genre'))
print(a)
# Out:
# 14

# %%
#ii. find items in each group:size()
genres=movies.groupby('Genre')
genres.size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
 #first()/last()/nth( ) item
genres.first()#gives first movies from all genre
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres.last()#gives last movie from all genre
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
genres.nth(3)#gives 4th movie from all genres
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 6                                         Pulp Fiction          1994      154
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 17                     One Flew Over the Cuckoo's Nest          1975      133
# 35                                    The Intouchables          2011      112
# 52                                         City Lights          1931       87
# 56                                      Kimi no na wa.          2016      106
# 110                                           Das Boot          1981      149
# 145                                     Shutter Island          2010      138
# 419                                       The Exorcist          1973      122
# 691                             The Outlaw Josey Wales          1976      135
#
#          Genre  IMDB_Rating           Director              Star1  \
# ...

# %%
#iv. get_group()
genres.get_group("Adventure")
# Out:
#                        Series_Title Released_Year  Runtime      Genre  \
# 21                     Interstellar          2014      169  Adventure
# 47               Back to the Future          1985      116  Adventure
# 93             Inglourious Basterds          2009      153  Adventure
# 110                        Das Boot          1981      149  Adventure
# 114           2001: A Space Odyssey          1968      149  Adventure
# ..                              ...           ...      ...        ...
# 957  Fear and Loathing in Las Vegas          1998      118  Adventure
# 964                        Dead Man          1995      121  Adventure
# 966                       Apollo 13            PG      140  Adventure
# 984                The Muppet Movie          1979       95  Adventure
# 991                  Kelly's Heroes          1970      144  Adventure
#
#      IMDB_Rating           Director                Star1  No_of_Votes  \
# ...

# %%
director=movies.groupby("Director")

# %%
director.get_group("Christopher Nolan")
# Out:
#               Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 2          The Dark Knight          2008      152     Action          9.0
# 8                Inception          2010      148     Action          8.8
# 21            Interstellar          2014      169  Adventure          8.6
# 36            The Prestige          2006      130      Drama          8.5
# 63   The Dark Knight Rises          2012      164     Action          8.4
# 69                 Memento          2000      113    Mystery          8.4
# 155          Batman Begins          2005      140     Action          8.2
# 573                Dunkirk          2017      106     Action          7.8
#
#               Director                Star1  No_of_Votes        Gross  \
# 2    Christopher Nolan       Christian Bale      2303232  534858444.0
# 8    Christopher Nolan    Leonardo DiCaprio      2067042  292576195.0
# 21   Christopher Nolan  Matthew McConaughey      1512360  188020017.0
# ...

# %%
#v. groups:
genres.groups#gives dictionary, group name as key and list of indexes as value
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
#v. describe()
genres.describe()#detail information of each columns
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
#sample()
genres.sample()#gives a random movie from each genre
# Out:
#                                      Series_Title Released_Year  Runtime  \
# 968                                  Falling Down          1993      113
# 226  Harry Potter and the Deathly Hallows: Part 2          2011      130
# 101                                     Toy Story          1995       81
# 770                                       Control          2007      122
# 978                  Planes, Trains & Automobiles          1987       93
# 1                                   The Godfather          1972      175
# 589                            La grande bellezza          2013      141
# 688                    E.T. the Extra-Terrestrial          1982      115
# 321                  Das Cabinet des Dr. Caligari          1920       76
# 309                                 The Third Man          1949      104
# 271                                     The Thing          1982      109
# 420                                        Sleuth          1972      138
# ...

# %%
#nunique()
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %% [markdown]
# agg method
# -> for the study of different columns by different mathematical interpretation

# %%
genres.agg(['sum','mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
# ...

# %%
genres.agg({
    'Runtime':'mean',
    'IMDB_Rating':'mean',
    'No_of_Votes':'sum'
})
# Out:
#               Runtime  IMDB_Rating  No_of_Votes
# Genre
# Action     129.046512     7.949419     72282412
# Adventure  134.111111     7.937500     22576163
# Animation   99.585366     7.930488     21978630
# Biography  136.022727     7.938636     24006844
# Comedy     112.129032     7.901290     27620327
# Crime      126.392523     8.016822     33533615
# Drama      124.737024     7.957439     61367304
# Family     107.500000     7.800000       551221
# Fantasy     85.000000     8.000000       146222
# Film-Noir  104.000000     7.966667       367215
# Horror     102.090909     7.909091      3742556
# Mystery    119.083333     7.975000      4203004
# Thriller   108.000000     7.800000        27733
# Western    148.250000     8.350000      1289665

# %%
#combining both
genres.agg({
    'Runtime':['sum','mean'],
    'No_of_Votes':['min']
})
# Out:
#           Runtime             No_of_Votes
#               sum        mean         min
# Genre
# Action      22196  129.046512       25312
# Adventure    9656  134.111111       29999
# Animation    8166   99.585366       25229
# Biography   11970  136.022727       27254
# Comedy      17380  112.129032       26337
# Crime       13524  126.392523       27712
# Drama       36049  124.737024       25088
# Family        215  107.500000      178731
# Fantasy       170   85.000000       57428
# Film-Noir     312  104.000000       59556
# Horror       1123  102.090909       27007
# Mystery      1429  119.083333       33982
# Thriller      108  108.000000       27733
# Western       593  148.250000       65659

# %%
genres.get_group("Action")
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
#looping on groups:
for group,data in genres:
    print(data['IMDB_Rating'].sort_values(ascending=False).head(1))
# Out:
# 2    9.0
# Name: IMDB_Rating, dtype: float64
# 21    8.6
# Name: IMDB_Rating, dtype: float64
# 23    8.6
# Name: IMDB_Rating, dtype: float64
# 7    8.9
# Name: IMDB_Rating, dtype: float64
# 19    8.6
# Name: IMDB_Rating, dtype: float64
# 1    9.2
# Name: IMDB_Rating, dtype: float64
# 0    9.3
# Name: IMDB_Rating, dtype: float64
# 688    7.8
# Name: IMDB_Rating, dtype: float64
# 321    8.1
# Name: IMDB_Rating, dtype: float64
# 309    8.1
# Name: IMDB_Rating, dtype: float64
# 49    8.5
# Name: IMDB_Rating, dtype: float64
# 69    8.4
# Name: IMDB_Rating, dtype: float64
# 700    7.8
# Name: IMDB_Rating, dtype: float64
# 12    8.8
# Name: IMDB_Rating, dtype: float64

# %%
##split apply and combine strategy:
#find number of movies starting with 'A' for each genre
def filter(group):
    return group['Series_Title'][group['Series_Title'].str.startswith('A')]

genres.apply(filter)
# Out:
# /tmp/ipykernel_5514/3876345567.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(filter)
# Genre
# Action  59          Avengers: Endgame
#         60     Avengers: Infinity War
#         106                    Aliens
#         166           Andaz Apna Apna
#         224               A Wednesday
#                         ...
# Drama   804             Abre los ojos
#         813         A Little Princess
#         824            A Few Good Men
#         903            A Star Is Born
# Horror  75                      Alien
# Name: Series_Title, Length: 63, dtype: object

# %%
##find ranking of each movie in the group according to IMDB Score
def ranking(group):
   group['Relative_Ranking'] =group['Metascore'].rank(ascending=False ) 
   return group
new=genres.apply(ranking) 
new[new['Genre']=='Crime']
# Out:
# /tmp/ipykernel_5514/826608286.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   new=genres.apply(ranking)
#                       Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# Genre
# Crime 1              The Godfather          1972      175  Crime          9.2
#       3     The Godfather: Part II          1974      202  Crime          9.0
#       4               12 Angry Men          1957       96  Crime          9.0
#       6               Pulp Fiction          1994      154  Crime          8.9
#       22            Cidade de Deus          2002      130  Crime          8.6
# ...                            ...           ...      ...    ...          ...
# ...

# %%
#find normalized rating
genres=movies.groupby('Genre')
def normalized_rating(group):
    group['Normalized_Rating']=(group['IMDB_Rating']-group['IMDB_Rating'].min())/(group['IMDB_Rating'].max()-group['IMDB_Rating'].min())
    return group
genres.apply(normalized_rating)
# Out:
# /tmp/ipykernel_5514/1726647340.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(normalized_rating)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...                                                         ...           ...
# ...

# %% [markdown]
# group of multiple columns

# %%
#Find most earning actor-director combo
duo=movies.groupby(['Star1','Director'])
duo['Gross'].sum().sort_values(ascending=False).head(1)
# Out:
# Star1           Director
# Toshirô Mifune  Akira Kurosawa    2.999877e+09
# Name: Gross, dtype: float64

# %%
#Find the best actor-genre combination in-terms of metascore
duo=movies.groupby(['Star1','Genre'])
duo['Metascore'].mean().sort_values(ascending=False).head(1)
# Out:
# Star1           Genre
# Ellar Coltrane  Drama    100.0
# Name: Metascore, dtype: float64

# %% [markdown]
# #agg on multiple groupby

# %%
duo=movies.groupby(['Genre','Director'])
duo.agg(['min','max'])
# Out:
#                                                    Series_Title  \
#                                                             min
# Genre    Director
# Action   Abhishek Chaubey                           Udta Punjab
#          Aditya Dhar                   Uri: The Surgical Strike
#          Akira Kurosawa                                     Ran
#          Alejandro G. Iñárritu                     The Revenant
#          Andrew Davis                              The Fugitive
# ...                                                         ...
# Mystery  Sujoy Ghosh                                    Kahaani
#          Terry Gilliam                           Twelve Monkeys
# Thriller Terence Young                          Wait Until Dark
# Western  Clint Eastwood                  The Outlaw Josey Wales
#          Sergio Leone           Il buono, il brutto, il cattivo
#
#                                                            Released_Year  \
# ...
